# %%
import czifile
import numpy as np
import matplotlib.pyplot as plt

# %%
czi = czifile.imread("data\RT_HC_10X_12-4-19_PLMD91_A.czi")
print("Number of Channels:",len(czi.shape))
print("Image Dimension:", czi.shape[5], czi.shape[6], czi.shape[3])
print("Shape", czi.shape)
# Out:
# Number of Channels: 8
# Image Dimension: 3072 2822 3
# Shape (1, 1, 1, 3, 1, 3072, 2822, 1)

# %%
#Extract Image from CZI File
img = czi[0,0,0,:,0,:,:,0]
img = img[0,:,:]
print("Image Shape:", img.shape)
# Out:
# Image Shape: (3072, 2822)

# %%
plt.figure(figsize = (10,10))
plt.imshow(img, cmap ="hot")
